# %% [markdown]
# # 🌎 Plotting.

# %% [markdown]
# ### In this Notebook we'll Do a Basic Plotting using the latest Data Points available as if they were prediction.

# %% [markdown]
# ### Importing Necessary Libraries.

# %%
import json
import time
from math import sqrt, radians
import numpy as np

import pandas as pd
import geopandas as gpd

import folium
import folium.plugins

import os
from dotenv import load_dotenv

load_dotenv("../.env")

import sys

sys.path.append("../Scripts/")
sys.path.append("../")

import paths
import config

# %% [markdown]
# ### First Things First, let's gather all our Raw Data Files in our Raw Data Directory, but Instead of creating a Gigatic DataFrame, this time we'll create one containing only the last record for each City.

# %%
Cities = config.Cities

os.listdir(paths.RAW_DATA_DIR)
# Out:
# ['Perugia_HistoricalData_01092022_29022024.parquet',
#  '.ipynb_checkpoints',
#  'Roma_HistoricalData_01092022_29022024.parquet',
#  'Bologna_HistoricalData_01092022_29022024.parquet',
#  'Trento_HistoricalData_01092022_29022024.parquet',
#  'Potenza_HistoricalData_01092022_29022024.parquet',
#  'Firenze_HistoricalData_01092022_29022024.parquet',
#  'Ancona_HistoricalData_01092022_29022024.parquet',
#  'Catanzaro_HistoricalData_01092022_29022024.parquet',
#  'Cagliari_HistoricalData_01092022_29022024.parquet',
#  'Venezia_HistoricalData_01092022_29022024.parquet',
#  'Genova_HistoricalData_01092022_29022024.parquet',
#  'Milano_HistoricalData_01092022_29022024.parquet',
#  'Bari_HistoricalData_01092022_29022024.parquet',
#  'Campobasso_HistoricalData_01092022_29022024.parquet',
#  'Trieste_HistoricalData_01092022_29022024.parquet',
#  "L'Aquila_HistoricalData_01092022_29022024.parquet",
#  'Palermo_HistoricalData_01092022_29022024.parquet',
#  'Torino_HistoricalData_01092022_29022024.parquet',
#  'Aosta_HistoricalData_01092022_29022024.parquet',
#  'Napoli_HistoricalData_01092022_29022024.parquet']

# %%
LastRecordDF = pd.DataFrame()

for file in os.listdir(paths.RAW_DATA_DIR):
    if file.endswith(".parquet"):
        #Splitting the FileName for '_' character and then getting the first item in the list as it's going to be the correspective name of the city.
        CityName = file.split("_")[0]
        print(f'Fetching Raw Data from Disk in Raw Data Dir for {CityName}')
        
        #Get the City ID for given City from Cities List
        CityID = next((x["CityID"] for x in Cities if x["CityName"] == CityName), None)
        Latitude = next((x["Latitude"] for x in Cities if x["CityName"] == CityName), None)
        Longitude = next((x["Longitude"] for x in Cities if x["CityName"] == CityName), None)

        print(f'Got City ID {CityID} with Coordinates: {Latitude, Longitude}')
        
        TempCityDF = pd.read_parquet(paths.RAW_DATA_DIR / file)
        
        #Creating a Single (Last) Record DataFrame
        
        #print([CityID, Latitude, Longitude, TempCityDF["EuropeanAQI"].iloc[-1]])
        LastRecord = pd.DataFrame(data = [[CityID, Latitude, Longitude, TempCityDF["EuropeanAQI"].iloc[-1]]], columns = ["CityID", "Latitude", "Longitude", "EuropeanAQI"])
                
        LastRecordDF = pd.concat([LastRecordDF, LastRecord])
# Out:
# Fetching Raw Data from Disk in Raw Data Dir for Perugia
# Got City ID PG with Coordinates: (43.110718, 12.390828)
# Fetching Raw Data from Disk in Raw Data Dir for Roma
# Got City ID RM with Coordinates: (41.902782, 12.496365)
# Fetching Raw Data from Disk in Raw Data Dir for Bologna
# Got City ID BO with Coordinates: (44.494888, 11.342616)
# Fetching Raw Data from Disk in Raw Data Dir for Trento
# Got City ID TN with Coordinates: (46.066669, 11.12907)
# Fetching Raw Data from Disk in Raw Data Dir for Potenza
# Got City ID PZ with Coordinates: (40.637241, 15.80222)
# Fetching Raw Data from Disk in Raw Data Dir for Firenze
# Got City ID FI with Coordinates: (43.769562, 11.255814)
# Fetching Raw Data from Disk in Raw Data Dir for Ancona
# Got City ID AN with Coordinates: (43.615849, 13.51874)
# Fetching Raw Data from Disk in Raw Data Dir for Catanzaro
# Got City ID CZ with Coordinates: (38.910542, 16.587761)
# Fetching Raw Data from Disk in Raw Data Dir for Cagliari
# Got City ID CA with Coordinates: (39.215408, 9.10932)
# Fetching Raw Data from Disk in Raw Data Dir for Venezia
# Got City ID VE with Coordinates: (45.440845, 12.315515)
# Fetching Raw Data from Disk in Raw Data Dir for Genova
# Got City ID GE with Coordinates: (44.405651, 8.946256)
# Fetching Raw Data from Disk in Raw Data Dir for Milano
# Got City ID MI with Coordinates: (45.464203, 9.189982)
# Fetching Raw Data from Disk in Raw Data Dir for Bari
# Got City ID BA with Coordinates: (41.125912, 16.87211)
# Fetching Raw Data from Disk in Raw Data Dir for Campobasso
# Got City ID CB with Coordinates: (41.56009, 14.6648)
# Fetching Raw Data from Disk in Raw Data Dir for Trieste
# Got City ID TS with Coordinates: (45.653599, 13.77852)
# Fetching Raw Data from Disk in Raw Data Dir for L'Aquila
# Got City ID AQ with Coordinates: (42.3507, 13.39993)
# Fetching Raw Data from Disk in Raw Data Dir for Palermo
# Got City ID PA with Coordinates: (38.115662, 13.36147)
# Fetching Raw Data from Disk in Raw Data Dir for Torino
# Got City ID TO with Coordinates: (45.070339, 7.686864)
# Fetching Raw Data from Disk in Raw Data Dir for Aosta
# Got City ID AO with Coordinates: (45.735062, 7.31308)
# Fetching Raw Data from Disk in Raw Data Dir for Napoli
# Got City ID NA with Coordinates: (40.851799, 14.26812)

# %%
#We Don't Care about all the Weather Data and the Datetimes, since we only need this sample.
LastRecordDF.reset_index(inplace = True)
LastRecordDF.drop("index", axis = 1, inplace = True)
LastRecordDF
# Out:
#    CityID   Latitude  Longitude  EuropeanAQI
# 0      PG  43.110718  12.390828           22
# 1      RM  41.902782  12.496365           27
# 2      BO  44.494888  11.342616           38
# 3      TN  46.066669  11.129070           63
# 4      PZ  40.637241  15.802220           17
# 5      FI  43.769562  11.255814           24
# 6      AN  43.615849  13.518740           34
# 7      CZ  38.910542  16.587761           26
# 8      CA  39.215408   9.109320           17
# 9      VE  45.440845  12.315515           33
# 10     GE  44.405651   8.946256           27
# 11     MI  45.464203   9.189982           73
# 12     BA  41.125912  16.872110           30
# 13     CB  41.560090  14.664800           16
# 14     TS  45.653599  13.778520           33
# 15     AQ  42.350700  13.399930           19
# 16     PA  38.115662  13.361470           22
# 17     TO  45.070339   7.686864           66
# 18     AO  45.735062   7.313080           26
# 19     NA  40.851799  14.268120           30

# %% [markdown]
# ### Next Up, let's create a GeoDataFrame for our LastRecordDF and add the geometry column with the Coordinates

# %%
Geometry = gpd.points_from_xy(LastRecordDF["Latitude"], LastRecordDF["Longitude"])
GeoDF = gpd.GeoDataFrame(
    LastRecordDF, geometry = Geometry
)

GeoDF
# Out:
#    CityID   Latitude  Longitude  EuropeanAQI                   geometry
# 0      PG  43.110718  12.390828           22  POINT (43.11072 12.39083)
# 1      RM  41.902782  12.496365           27  POINT (41.90278 12.49637)
# 2      BO  44.494888  11.342616           38  POINT (44.49489 11.34262)
# 3      TN  46.066669  11.129070           63  POINT (46.06667 11.12907)
# 4      PZ  40.637241  15.802220           17  POINT (40.63724 15.80222)
# 5      FI  43.769562  11.255814           24  POINT (43.76956 11.25581)
# 6      AN  43.615849  13.518740           34  POINT (43.61585 13.51874)
# 7      CZ  38.910542  16.587761           26  POINT (38.91054 16.58776)
# 8      CA  39.215408   9.109320           17   POINT (39.21541 9.10932)
# 9      VE  45.440845  12.315515           33  POINT (45.44085 12.31551)
# 10     GE  44.405651   8.946256           27   POINT (44.40565 8.94626)
# 11     MI  45.464203   9.189982           73   POINT (45.46420 9.18998)
# 12     BA  41.125912  16.872110           30  POINT (41.12591 16.87211)
# 13     CB  41.560090  14.664800           16  POINT (41.56009 14.66480)
# 14     TS  45.653599  13.778520           33  POINT (45.65360 13.77852)
# 15     AQ  42.350700  13.399930           19  POINT (42.35070 13.39993)
# 16     PA  38.115662  13.361470           22  POINT (38.11566 13.36147)
# 17     TO  45.070339   7.686864           66   POINT (45.07034 7.68686)
# 18     AO  45.735062   7.313080           26   POINT (45.73506 7.31308)
# 19     NA  40.851799  14.268120           30  POINT (40.85180 14.26812)

# %% [markdown]
# ### Then let's Create our Map.

# %%
Map = folium.Map(location=[41.50, 16.50], tiles = "Esri.WorldPhysical", zoom_start = 6,
               zoom_control = True,
               scrollWheelZoom = True,
               dragging = True)

# %%
Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fcdcab411ca0d4805ceb8d6aeae6b21f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fcdcab411ca0d4805ceb8d6aeae6b21f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fcdcab411ca0d4805ceb8d6aeae6b21f = L.map(
#                 &quot;map_fcdcab411ca0d4805ceb8d6aeae6b21f&quot;,
#                 {
#                     center: [41.5, 16.5],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     scrollWheelZoom: true,
#                     dragging: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d7287b256f63cad95bfc87a9fdac135b = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Physical_Map/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: US National Park Service&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 8, &quot;maxZoom&quot;: 8, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d7287b256f63cad95bfc87a9fdac135b.addTo(map_fcdcab411ca0d4805ceb8d6aeae6b21f);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Now, let's add Markers for each City to the Map, with Respective City Name

# %%
for row in LastRecordDF.iterrows():
    
    CityID = row[1]["CityID"]
    Latitude = row[1]["Latitude"]
    Longitude = row[1]["Longitude"]
    EuropeanAQI = row[1]["EuropeanAQI"]

    if EuropeanAQI < 20:
        Color = "green"
    
    elif EuropeanAQI < 40 and EuropeanAQI >= 20:
        Color = "beige"
    
    elif EuropeanAQI < 60 and EuropeanAQI >= 40:
        Color = "orange"
    
    elif EuropeanAQI < 80 and EuropeanAQI >= 60:
        Color = "red"
    
    elif EuropeanAQI < 100 and EuropeanAQI >= 80:
        Color = "darkred"
    
    elif EuropeanAQI >= 100:
        color = "black"

    #Place the markers with the popup labels and data
    Map.add_child(folium.Marker(
                                location = (Latitude, Longitude),
                                popup =
                                "CityID: " + str(CityID) + "<br>" + "PredictedAQI: " + str(EuropeanAQI) + "<br>",
                                icon = folium.Icon(color="%s" % Color),
                            )
                        )

# %%
Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fcdcab411ca0d4805ceb8d6aeae6b21f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fcdcab411ca0d4805ceb8d6aeae6b21f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fcdcab411ca0d4805ceb8d6aeae6b21f = L.map(
#                 &quot;map_fcdcab411ca0d4805ceb8d6aeae6b21f&quot;,
#                 {
#                     center: [41.5, 16.5],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     scrollWheelZoom: true,
#                     dragging: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d7287b256f63cad95bfc87a9fdac135b = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Physical_Map/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: US National Park Service&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 8, &quot;maxZoom&quot;: 8, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d7287b256f63cad95bfc87a9fdac135b.addTo(map_fcdcab411ca0d4805ceb8d6aeae6b21f);
#
#
#             tile_layer_d7287b256f63cad95bfc87a9fdac135b.addTo(map_fcdcab411ca0d4805ceb8d6aeae6b21f);
#
#
#             var marker_8478d050fd63413a18d71e1edd2a5cff = L.marker(
#                 [43.110718, 12.390828],
#                 {}
#             ).addTo(map_fcdcab411ca0d4805ceb8d6aeae6b21f);
#
#
#             var icon_61eb32398cf7954a189a83c48e07608a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8478d050fd63413a18d71e1edd2a5cff.setIcon(icon_61eb32398cf7954a189a83c48e07608a);
#
#
#         var popup_f4f02d04047304c93bfd04a801f78c08 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_11db472ba59a8212b6879604dfb34262 = $(`&lt;div id=&quot;html_11db472ba59a8212b6879604dfb34262&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CityID: PG&lt;br&gt;PredictedAQI: 22&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_f4f02d04047304c93bfd04a801f78c08.setContent(html_11db472ba59a8212b6879604dfb34262);
#
#
#
#         marker_8478d050fd63413a18d71e1edd2a5cff.bindPopup(popup_f4f02d04047304c93bfd04a801f78c08)
#         ;
#
#
#
#
#             var marker_45b6eb1fda16e8560d28bc6f19d93142 = L.marker(
#                 [41.902782, 12.496365],
#                 {}
#             ).addTo(map_fcdcab411ca0d4805ceb8d6aeae6b21f);
#
#
#             var icon_130a700ca47f152e35f04600d545ab35 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_45b6eb1fda16e8560d28bc6f19d93142.setIcon(icon_130a700ca47f152e35f04600d545ab35);
#
#
#         var popup_60231f9af46005b272245a656b0c4cf1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_08432e55b5b4079ff1e3f4b8c9bcd3cb = $(`&lt;div id=&quot;html_08432e55b5b4079ff1e3f4b8c9bcd3cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CityID: RM&lt;br&gt;PredictedAQI: 27&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_60231f9af46005b272245a656b0c4cf1.setContent(html_08432e55b5b4079ff1e3f4b8c9bcd3cb);
#
#
#
#         marker_45b6eb1fda16e8560d28bc6f19d93142.bindPopup(popup_60231f9af46005b272245a656b0c4cf1)
#         ;
#
#
#
#
#             var marker_cf540b8612e85010617efb82f30b778c = L.marker(
#                 [44.494888, 11.342616],
#                 {}
#             ).addTo(map_fcdcab411ca0d4805ceb8d6aeae6b21f);
#
#
#             var icon_e1d23e9fd84fd2b838a0497c819cc858 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cf540b8612e85010617efb82f30b778c.setIcon(icon_e1d23e9fd84fd2b838a0497c819cc858);
#
#
#         var popup_e790c6058a90372570f1c7fecc9c7846 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_34fcc6a13a11c0eafdfa8b4ffb172c43 = $(`&lt;div id=&quot;html_34fcc6a13a11c0eafdfa8b4ffb172c43&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CityID: BO&lt;br&gt;PredictedAQI: 38&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_e790c6058a90372570f1c7fecc9c7846.setContent(html_34fcc6a13a11c0eafdfa8b4ffb172c43);
#
#
#
#         marker_cf540b8612e85010617efb82f30b778c.bindPopup(popup_e790c6058a90372570f1c7fecc9c7846)
#         ;
#
#
#
#
#             var marker_0b59e603c187b0f1cdec959403f20885 = L.marker(
#                 [46.066669, 11.12907],
#                 {}
#             ).addTo(map_fcdcab411ca0

# %% [markdown]
# ### Lastly, we need to Create our Heat Data to give those HeatMap vibes and to give context to our map visualization.

# %%
HeatData = []

for row in LastRecordDF.iterrows():
    CityID = row[1]["CityID"]
    Coordinates = [row[1]["Latitude"], row[1]["Longitude"]]
    EuropeanAQI = row[1]["EuropeanAQI"]
    Data = [row[1]["Latitude"], row[1]["Longitude"], EuropeanAQI]
    
    #The Heatmap wants Data in format [Latitude, Longitude] or [Latitude, Longitude, Value]
    HeatData.append(Data)
    

HeatMap = Map
folium.plugins.HeatMap(HeatData, radius = 50, blur = 50).add_to(HeatMap)
HeatMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fcdcab411ca0d4805ceb8d6aeae6b21f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fcdcab411ca0d4805ceb8d6aeae6b21f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fcdcab411ca0d4805ceb8d6aeae6b21f = L.map(
#                 &quot;map_fcdcab411ca0d4805ceb8d6aeae6b21f&quot;,
#                 {
#                     center: [41.5, 16.5],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     scrollWheelZoom: true,
#                     dragging: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d7287b256f63cad95bfc87a9fdac135b = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Physical_Map/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: US National Park Service&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 8, &quot;maxZoom&quot;: 8, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d7287b256f63cad95bfc87a9fdac135b.addTo(map_fcdcab411ca0d4805ceb8d6aeae6b21f);
#
#
#             tile_layer_d7287b256f63cad95bfc87a9fdac135b.addTo(map_fcdcab411ca0d4805ceb8d6aeae6b21f);
#
#
#             var marker_8478d050fd63413a18d71e1edd2a5cff = L.marker(
#                 [43.110718, 12.390828],
#                 {}
#             ).addTo(map_fcdcab411ca0d4805ceb8d6aeae6b21f);
#
#
#             var icon_61eb32398cf7954a189a83c48e07608a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8478d050fd63413a18d71e1edd2a5cff.setIcon(icon_61eb32398cf7954a189a83c48e07608a);
#
#
#         var popup_f4f02d04047304c93bfd04a801f78c08 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_11db472ba59a8212b6879604dfb34262 = $(`&lt;div id=&quot;html_11db472ba59a8212b6879604dfb34262&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CityID: PG&lt;br&gt;PredictedAQI: 22&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_f4f02d04047304c93bfd04a801f78c08.setContent(html_11db472ba59a8212b6879604dfb34262);
#
#
#
#         marker_8478d050fd63413a18d71e1edd2a5cff.bindPopup(popup_f4f02d04047304c93bfd04a801f78c08)
#         ;
#
#
#
#
#             var marker_45b6eb1fda16e8560d28bc6f19d93142 = L.marker(
#                 [41.902782, 12.496365],
#                 {}
#             ).addTo(map_fcdcab411ca0d4805ceb8d6aeae6b21f);
#
#
#             var icon_130a700ca47f152e35f04600d545ab35 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_45b6eb1fda16e8560d28bc6f19d93142.setIcon(icon_130a700ca47f152e35f04600d545ab35);
#
#
#         var popup_60231f9af46005b272245a656b0c4cf1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_08432e55b5b4079ff1e3f4b8c9bcd3cb = $(`&lt;div id=&quot;html_08432e55b5b4079ff1e3f4b8c9bcd3cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CityID: RM&lt;br&gt;PredictedAQI: 27&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_60231f9af46005b272245a656b0c4cf1.setContent(html_08432e55b5b4079ff1e3f4b8c9bcd3cb);
#
#
#
#         marker_45b6eb1fda16e8560d28bc6f19d93142.bindPopup(popup_60231f9af46005b272245a656b0c4cf1)
#         ;
#
#
#
#
#             var marker_cf540b8612e85010617efb82f30b778c = L.marker(
#                 [44.494888, 11.342616],
#                 {}
#             ).addTo(map_fcdcab411ca0d4805ceb8d6aeae6b21f);
#
#
#             var icon_e1d23e9fd84fd2b838a0497c819cc858 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cf540b8612e85010617efb82f30b778c.setIcon(icon_e1d23e9fd84fd2b838a0497c819cc858);
#
#
#         var popup_e790c6058a90372570f1c7fecc9c7846 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_34fcc6a13a11c0eafdfa8b4ffb172c43 = $(`&lt;div id=&quot;html_34fcc6a13a11c0eafdfa8b4ffb172c43&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CityID: BO&lt;br&gt;PredictedAQI: 38&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_e790c6058a90372570f1c7fecc9c7846.setContent(html_34fcc6a13a11c0eafdfa8b4ffb172c43);
#
#
#
#         marker_cf540b8612e85010617efb82f30b778c.bindPopup(popup_e790c6058a90372570f1c7fecc9c7846)
#         ;
#
#
#
#
#             va

# %% [markdown]
# ### As you can see, our Map is quite Explainatory.
# ### In Northern Italy Air Quality is worse due to Industrial Activity, so our Data makes sense.
# ### Also, Northern Cities with that usually are windy, such as Genova and Trieste, have lower AQI.
# ### However, that being said, our Map is still not as good as I would like it to be, so let's tweak it a bit.
# ### First, we would need to add coordinates points for each ray going from the Each City to the nearest one.
# ### Then we would need to make AQI as if it's transitioning from one city to another, to give that "blur" effect and not leave empty spaces.
# ### Lastly we need to tweak the color palette, so we make sure that each city has a more appropriate color.

# %%
#Let's First create a copy of our previous Map.
NewHeatMap = Map

# %%
#Let's Copy our LastRecordDF and Sort it by Latitude.
NewLastRecordDF = LastRecordDF.copy()
NewLastRecordDF.sort_values(by = "Latitude", inplace = True, ascending = False)

for row in NewLastRecordDF.iterrows():
    print(row[1])
# Out:
# CityID                TN
# Latitude       46.066669
# Longitude       11.12907
# EuropeanAQI           63
# Name: 3, dtype: object
# CityID                AO
# Latitude       45.735062
# Longitude        7.31308
# EuropeanAQI           26
# Name: 18, dtype: object
# CityID                TS
# Latitude       45.653599
# Longitude       13.77852
# EuropeanAQI           33
# Name: 14, dtype: object
# CityID                MI
# Latitude       45.464203
# Longitude       9.189982
# EuropeanAQI           73
# Name: 11, dtype: object
# CityID                VE
# Latitude       45.440845
# Longitude      12.315515
# EuropeanAQI           33
# Name: 9, dtype: object
# CityID                TO
# Latitude       45.070339
# Longitude       7.686864
# EuropeanAQI           66
# Name: 17, dtype: object
# CityID                BO
# Latitude       44.494888
# Longitude      11.342616
# EuropeanAQI           38
# Name: 2, dtype: object
# CityID                GE
# Latitude       44.405651
# Longitude       8.946256
# EuropeanAQI           27
# Name: 10, dtype: object
# CityID                FI
# Latitude       43.769562
# Longitude      11.255814
# EuropeanAQI           24
# Name: 5, dtype: object
# CityID                AN
# Latitude       43.615849
# Longitude       13.51874
# EuropeanAQI           34
# Name: 6, dtype: object
# CityID                PG
# Latitude       43.110718
# Longitude      12.390828
# EuropeanAQI           22
# Name: 0, dtype: object
# CityID               AQ
# Latitude        42.3507
# Longitude      13.39993
# EuropeanAQI          19
# Name: 15, dtype: object
# CityID                RM
# Latitude       41.902782
# Longitude      12.496365
# EuropeanAQI           27
# Name: 1, dtype: object
# CityID               CB
# Latitude       41.56009
# Longitude       14.6648
# EuropeanAQI          16
# Name: 13, dtype: object
# CityID                BA
# Latitude       41.125912
# Longitude       16.87211
# EuropeanAQI           30
# Name: 12, dtype: object
# CityID                NA
# Latitude       40.851799
# Longitude       14.26812
# EuropeanAQI           30
# Name: 19, dtype: object
# CityID                PZ
# Latitude       40.637241
# Longitude       15.80222
# EuropeanAQI           17
# Name: 4, dtype: object
# CityID                CA
# Latitude       39.215408
# Longitude        9.10932
# EuropeanAQI           17
# Name: 8, dtype: object
# CityID                CZ
# Latitude       38.910542
# Longitude      16.587761
# EuropeanAQI           26
# Name: 7, dtype: object
# CityID                PA
# Latitude       38.115662
# Longitude       13.36147
# EuropeanAQI           22
# Name: 16, dtype: object

# %%
#Now that our DataFrame is sorted in Descending order, let's fill it with coordinates of Intermidiate Points in the Map.

#Just to give an Example, say that we want 10 Intermediate Points between Point A with Coordinates (5, 1) and Point B with Coordinates (3, 2)

latitudes = np.linspace(5, 3, 10 + 2)
longitudes = np.linspace(1, 2, 10 + 2)
intermediates = [(lat, lon) for lat, lon in zip(latitudes, longitudes)]
print(intermediates)

#Now, how do we define how many intermediate Points we want for each Pair A-B?
#As a rule of thumb, we'll add a point for every 0.1 fifference (rounded for excess) in Latitude and 1 point for every 0.10 difference in Longitude
#And how do we find for which Pair of Cities (Point A and B) we would like to have those intermediate Points?
#As another rule of thumb, we'll DEFINE MANUALLY all the pairs of points we would like to get the Intermediate Points.
#Going Manual on this task might seem time consuming, but as the DataFrame has only 20 entries, it's no drama, a better approach for bigger dataframes would be to find X nearest neighbors.
#We can do so much more Engineering on this Map, but I think this will do the work as we want a very simple viz.
# Out:
# [(5.0, 1.0), (4.818181818181818, 1.0909090909090908), (4.636363636363637, 1.1818181818181819), (4.454545454545455, 1.2727272727272727), (4.2727272727272725, 1.3636363636363638), (4.090909090909091, 1.4545454545454546), (3.909090909090909, 1.5454545454545454), (3.7272727272727275, 1.6363636363636362), (3.5454545454545454, 1.7272727272727273), (3.3636363636363633, 1.8181818181818183), (3.1818181818181817, 1.9090909090909092), (3.0, 2.0)]

# %%
PairsIDsToDo = [["AO", "TO"],
                ["AO", "TN"],
                ["AO", "MI"],
                ["TO", "MI"],
                ["TO", "GE"],
                ["MI", "GE"],
                ["MI", "TN"],
                ["MI", "BO"],
                ["MI", "VE"],
                ["GE", "BO"],
                ["GE", "FI"],
                ["TN", "VE"],
                ["TN", "TS"],
                ["VE", "TS"],
                ["VE", "BO"],
                ["BO", "AN"],
                ["BO", "FI"],
                ["FI", "RM"],
                ["FI", "PG"],
                ["FI", "AN"],
                ["PG", "AN"],
                ["PG", "AQ"],
                ["PG", "RM"],
                ["AN", "AQ"],
                ["RM", "AQ"],
                ["RM", "NA"],
                ["RM", "CB"],
                ["AQ", "CB"],
                ["NA", "CB"],
                ["NA", "PZ"],
                ["CB", "BA"],
                ["CB", "PZ"],
                ["PZ", "BA"],
                ["PZ", "CZ"],
                ["CZ", "PA"],
                #["PA", "CA"]
               ]

#It took less than 5 Minutes, let's now plot a line connecting all points to see if they are correct.

# %%
for pair in PairsIDsToDo:

    PointA = NewLastRecordDF[NewLastRecordDF["CityID"] == pair[0]]
    PointB = NewLastRecordDF[NewLastRecordDF["CityID"] == pair[1]]
    
    PointA_Coords = [PointA["Latitude"].values[0], PointA["Longitude"].values[0]]
    PointB_Coords = [PointB["Latitude"].values[0], PointB["Longitude"].values[0]]
    
    folium.PolyLine(locations=[PointA_Coords, PointB_Coords], color='blue').add_to(NewHeatMap)

# %%
NewHeatMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fcdcab411ca0d4805ceb8d6aeae6b21f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fcdcab411ca0d4805ceb8d6aeae6b21f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fcdcab411ca0d4805ceb8d6aeae6b21f = L.map(
#                 &quot;map_fcdcab411ca0d4805ceb8d6aeae6b21f&quot;,
#                 {
#                     center: [41.5, 16.5],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     scrollWheelZoom: true,
#                     dragging: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d7287b256f63cad95bfc87a9fdac135b = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Physical_Map/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: US National Park Service&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 8, &quot;maxZoom&quot;: 8, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d7287b256f63cad95bfc87a9fdac135b.addTo(map_fcdcab411ca0d4805ceb8d6aeae6b21f);
#
#
#             tile_layer_d7287b256f63cad95bfc87a9fdac135b.addTo(map_fcdcab411ca0d4805ceb8d6aeae6b21f);
#
#
#             var marker_8478d050fd63413a18d71e1edd2a5cff = L.marker(
#                 [43.110718, 12.390828],
#                 {}
#             ).addTo(map_fcdcab411ca0d4805ceb8d6aeae6b21f);
#
#
#             var icon_61eb32398cf7954a189a83c48e07608a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8478d050fd63413a18d71e1edd2a5cff.setIcon(icon_61eb32398cf7954a189a83c48e07608a);
#
#
#         var popup_f4f02d04047304c93bfd04a801f78c08 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_11db472ba59a8212b6879604dfb34262 = $(`&lt;div id=&quot;html_11db472ba59a8212b6879604dfb34262&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CityID: PG&lt;br&gt;PredictedAQI: 22&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_f4f02d04047304c93bfd04a801f78c08.setContent(html_11db472ba59a8212b6879604dfb34262);
#
#
#
#         marker_8478d050fd63413a18d71e1edd2a5cff.bindPopup(popup_f4f02d04047304c93bfd04a801f78c08)
#         ;
#
#
#
#
#             var marker_45b6eb1fda16e8560d28bc6f19d93142 = L.marker(
#                 [41.902782, 12.496365],
#                 {}
#             ).addTo(map_fcdcab411ca0d4805ceb8d6aeae6b21f);
#
#
#             var icon_130a700ca47f152e35f04600d545ab35 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_45b6eb1fda16e8560d28bc6f19d93142.setIcon(icon_130a700ca47f152e35f04600d545ab35);
#
#
#         var popup_60231f9af46005b272245a656b0c4cf1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_08432e55b5b4079ff1e3f4b8c9bcd3cb = $(`&lt;div id=&quot;html_08432e55b5b4079ff1e3f4b8c9bcd3cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CityID: RM&lt;br&gt;PredictedAQI: 27&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_60231f9af46005b272245a656b0c4cf1.setContent(html_08432e55b5b4079ff1e3f4b8c9bcd3cb);
#
#
#
#         marker_45b6eb1fda16e8560d28bc6f19d93142.bindPopup(popup_60231f9af46005b272245a656b0c4cf1)
#         ;
#
#
#
#
#             var marker_cf540b8612e85010617efb82f30b778c = L.marker(
#                 [44.494888, 11.342616],
#                 {}
#             ).addTo(map_fcdcab411ca0d4805ceb8d6aeae6b21f);
#
#
#             var icon_e1d23e9fd84fd2b838a0497c819cc858 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cf540b8612e85010617efb82f30b778c.setIcon(icon_e1d23e9fd84fd2b838a0497c819cc858);
#
#
#         var popup_e790c6058a90372570f1c7fecc9c7846 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_34fcc6a13a11c0eafdfa8b4ffb172c43 = $(`&lt;div id=&quot;html_34fcc6a13a11c0eafdfa8b4ffb172c43&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CityID: BO&lt;br&gt;PredictedAQI: 38&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_e790c6058a90372570f1c7fecc9c7846.setContent(html_34fcc6a13a11c0eafdfa8b4ffb172c43);
#
#
#
#         marker_cf540b8612e85010617efb82f30b778c.bindPopup(popup_e790c6058a90372570f1c7fecc9c7846)
#         ;
#
#
#
#
#             va

# %% [markdown]
# ### Perfect, now, let's Move on with creating the intermediate points and let's Reecreate our Map and place the Markers.

# %%
#Copying the DF
FilledLastRecordDF = NewLastRecordDF.copy()

#Defining a Function to calculate the Euclidean Distance as if Earth was Flat.
#I DO NOT BELIEVE EARTH IS FLAT, but in shorter distances and far from the poles, earth curvature is negotiable.
#A more precise method would be calculating Haversine Distance.
def EuclideanDistance(Point1_Coords, Point2_Coords):
    #Convert latitude and longitude from degrees to radians
    Lat1, Lon1, Lat2, Lon2 = map(radians, [Point1_Coords[0], Point1_Coords[1], Point2_Coords[0], Point2_Coords[1]])

    #Calculate differences in latitude and longitude
    LatDiff = abs(Lat2 - Lat1)
    LonDiff = abs(Lon2 - Lon1)
    
    #Calculate Euclidean distance
    Distance = sqrt(LatDiff**2 + LonDiff**2)
    #print(f'Distance: {round(Distance, 6)}')
    
    return round(Distance, 6)

#Defining a Function to Calculate the Synthetic EuropeanAQI of Intermediate Point.
def CalculateSyntheticEAQI(EAQI_A, EAQI_B, PointA_Coords, PointB_Coords, PointX_Coords):
    
    EAQI_Diff = EAQI_B - EAQI_A
    DistancePercentage = EuclideanDistance(PointA_Coords, PointX_Coords) / EuclideanDistance(PointA_Coords, PointB_Coords)
    EAQI_X = EAQI_A + EAQI_Diff * DistancePercentage
    
    #print(f'EAQI_A: {EAQI_A}')
    #print(f'EAQI_X: {int(EAQI_X)}')
    #print(f'EAQI_B: {EAQI_B}')
    
    return int(EAQI_X)

for pair in PairsIDsToDo:

    #Getting PointA and PointB rows given 2 City IDs, then getting the coordinates, generating the intermediate point and lastly, inserting a "fake" City ID as First Element
    #and a Synthetic European AQI as Last Element.
    PointA = NewLastRecordDF[NewLastRecordDF["CityID"] == pair[0]]
    PointB = NewLastRecordDF[NewLastRecordDF["CityID"] == pair[1]]
    
    PointA_Coords = [PointA["Latitude"].values[0], PointA["Longitude"].values[0]]
    PointB_Coords = [PointB["Latitude"].values[0], PointB["Longitude"].values[0]]
    
    NumIntermediates = int(abs(PointA_Coords[0] - PointB_Coords[0]) * 10) + int(abs(PointA_Coords[1] - PointB_Coords[1]) * 10)
    
    Lats = np.linspace(PointA_Coords[0], PointB_Coords[0], NumIntermediates + 2)
    Longs = np.linspace(PointA_Coords[1], PointB_Coords[1], NumIntermediates + 2)
    
    IntermediatePoints = [[round(lat, 6), round(lon, 6)] for lat, lon in zip(Lats, Longs)]
    #Cutting off First and Last Elements as they are PointA and PointB
    IntermediatePoints = IntermediatePoints[1:-1]
    
    print(f'Start Point: {PointA_Coords}')
    print(f'Intermediates: {IntermediatePoints}')
    print(f'End Point: {PointB_Coords}')
    
    for intermediate in IntermediatePoints:
        IntermediateCoords = intermediate.copy()
        
        intermediate.insert(0, "IntermediatePoint")
        #Let's add those points to the DataFrame with a "IntermediatePoint" ID and a EuropeanAQI Value
        intermediate.append(CalculateSyntheticEAQI(PointA["EuropeanAQI"].values[0], PointB["EuropeanAQI"].values[0], PointA_Coords, PointB_Coords, IntermediateCoords))
    
        FilledLastRecordDF = pd.concat([FilledLastRecordDF, pd.DataFrame([[x for x in intermediate]], columns = FilledLastRecordDF.columns)], ignore_index=True)
# Out:
# Start Point: [45.735062, 7.31308]
# Intermediates: [[45.66859, 7.350458], [45.602117, 7.387837], [45.535645, 7.425215], [45.469173, 7.462594], [45.4027, 7.499972], [45.336228, 7.53735], [45.269756, 7.574729], [45.203284, 7.612107], [45.136811, 7.649486]]
# End Point: [45.070339, 7.686864]
# Start Point: [45.735062, 7.31308]
# Intermediates: [[45.742957, 7.403937], [45.750853, 7.494794], [45.758748, 7.585651], [45.766644, 7.676508], [45.774539, 7.767365], [45.782434, 7.858221], [45.79033, 7.949078], [45.798225, 8.039935], [45.806121, 8.130792], [45.814016, 8.221649], [45.821911, 8.312506], [45.829807, 8.403363], [45.837702, 8.49422], [45.845598, 8.585077], [45.853493, 8.675934], [45.861388, 8.76679], [45.869284, 8.857647], [45.877179, 8.948504], [45.885075, 9.039361], [45.89297, 9.130218], [45.900865, 9.221075], [45.908761, 9.311932], [45.916656, 9.402789], [45.924552, 9.493646], [45.932447, 9.584503], [45.940343, 9.67536], [45.948238, 9.766216], [45.956133, 9.857073], [45.964029, 9.94793], [45.971924, 10.038787], [45.97982, 10.129644], [45.987715, 10.220501], [45.99561, 10.311358], [46.003506, 10.402215], [46.011401, 10.493072], [46.019297, 10.583929], [46.027192, 10.674785], [46.035087, 10.765642], [46.042983, 10.856499], [46.050878, 10.947356], [46.058774, 11.038213]]
# End Point: [46.066669, 11.12907]
# Start Point: [45.735062, 7.31308]
# Intermediates: [[38.89067, 16.507104], [38.870798, 16.426446], [38.850926, 16.345789], [38.831054, 16.265132], [38.811182, 16.184475], [38.79131, 16.103817], [38.771438, 16.02316], [38.751566, 15.942503], [38.731694, 15.861846], [38.711822, 15.781188], [38.69195, 15.700531], [38.672078, 15.619874], [38.652206, 15.539216], [38.632334, 15.458559], [38.612462, 15.377902], [38.59259, 15.297245], [38.572718, 15.216587], [38.552846, 15.13593], [38.532974, 15.055273], [38.513102, 14.974616], [38.49323, 14.893958], [38.473358, 14.813301], [38.453486, 14.732644], [38.433614, 14.651986], [38.413742, 14.571329], [38.39387, 14.490672], [38.373998, 14.410015], [38.354126, 14.329357], [38.334254, 14.2487], [38.314382, 14.168043], [38.29451, 14.087385], [38.274638, 14.006728], [38.254766, 13.926071], [38.234894, 13.845414], [38.215022, 13.764756], [38.19515, 13.684099], [38.175278, 13.603442], [38.155406, 13.522785], [38.135534, 13.442127]]
# End Point: [38.115662, 13.36147]

# %%
#Let's sort again this last DataFrame by Latitude.
SortedFilledLastRecordDF = FilledLastRecordDF.copy()
SortedFilledLastRecordDF.sort_values(by = "Latitude", inplace = True, ascending = False)
SortedFilledLastRecordDF
# Out:
#                 CityID   Latitude  Longitude  EuropeanAQI
# 0                   TN  46.066669  11.129070           63
# 69   IntermediatePoint  46.058774  11.038213           62
# 293  IntermediatePoint  46.053344  11.214536           62
# 68   IntermediatePoint  46.050878  10.947356           61
# 162  IntermediatePoint  46.043497  11.054490           63
# ..                 ...        ...        ...          ...
# 751  IntermediatePoint  38.195150  13.684099           22
# 752  IntermediatePoint  38.175278  13.603442           22
# 753  IntermediatePoint  38.155406  13.522785           22
# 754  IntermediatePoint  38.135534  13.442127           22
# 19                  PA  38.115662  13.361470           22
#
# [755 rows x 4 columns]

# %% [markdown]
# ### Now, let's recreate the map, place the Markers (Colored for Actual Data and Gray for Synthetic) and draw the lines to see if they fit well.

# %%
#Creating the Map
FinalMap = folium.Map(location=[41.50, 16.50], tiles = "Esri.WorldPhysical", zoom_start = 6,
               zoom_control = True,
               scrollWheelZoom = True,
               dragging = True)

#Adding Markers, Colored for Real Data, Gray for Synthetic One.
for row in SortedFilledLastRecordDF.iterrows():
    
    CityID = row[1]["CityID"]
    Latitude = row[1]["Latitude"]
    Longitude = row[1]["Longitude"]
    EuropeanAQI = row[1]["EuropeanAQI"]

    if CityID != "IntermediatePoint": 
        
        if EuropeanAQI < 20:
            Color = "green"

        elif EuropeanAQI < 40 and EuropeanAQI >= 20:
            Color = "beige"

        elif EuropeanAQI < 60 and EuropeanAQI >= 40:
            Color = "orange"

        elif EuropeanAQI < 80 and EuropeanAQI >= 60:
            Color = "red"

        elif EuropeanAQI < 100 and EuropeanAQI >= 80:
            Color = "darkred"

        elif EuropeanAQI >= 100:
            Color = "black"

    else:
        Color = "gray"
        
    #Place the markers with the popup labels and data
    FinalMap.add_child(folium.Marker(
                                location = (Latitude, Longitude),
                                popup =
                                "CityID: " + str(CityID) + "<br>" + "PredictedAQI: " + str(EuropeanAQI) + "<br>",
                                icon = folium.Icon(color="%s" % Color),
                            )
                        )

#Adding Lines that connect Points.
for pair in PairsIDsToDo:

    PointA = NewLastRecordDF[NewLastRecordDF["CityID"] == pair[0]]
    PointB = NewLastRecordDF[NewLastRecordDF["CityID"] == pair[1]]
    
    PointA_Coords = [PointA["Latitude"].values[0], PointA["Longitude"].values[0]]
    PointB_Coords = [PointB["Latitude"].values[0], PointB["Longitude"].values[0]]
    
    folium.PolyLine(locations=[PointA_Coords, PointB_Coords], color='blue').add_to(FinalMap)

# %%
#Render Map
FinalMap

#P.S.: It seems messy at first, but just Zoom in and you'll know it's perfect.
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3b7a8392c718fc28e3e4aae3c686b08c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3b7a8392c718fc28e3e4aae3c686b08c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3b7a8392c718fc28e3e4aae3c686b08c = L.map(
#                 &quot;map_3b7a8392c718fc28e3e4aae3c686b08c&quot;,
#                 {
#                     center: [41.5, 16.5],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     scrollWheelZoom: true,
#                     dragging: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_37c9f8b906d80a858d989abbf88f550a = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Physical_Map/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: US National Park Service&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 8, &quot;maxZoom&quot;: 8, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_37c9f8b906d80a858d989abbf88f550a.addTo(map_3b7a8392c718fc28e3e4aae3c686b08c);
#
#
#             var marker_99dcf5788213ef2719672f5df6602764 = L.marker(
#                 [46.066669, 11.12907],
#                 {}
#             ).addTo(map_3b7a8392c718fc28e3e4aae3c686b08c);
#
#
#             var icon_66e096094efd6322c63c221527d1dd3d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_99dcf5788213ef2719672f5df6602764.setIcon(icon_66e096094efd6322c63c221527d1dd3d);
#
#
#         var popup_7325efd7bbc06da56c2fc23ce0fd9b77 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_026bad119ec162a2d42fc24d34d5b188 = $(`&lt;div id=&quot;html_026bad119ec162a2d42fc24d34d5b188&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CityID: TN&lt;br&gt;PredictedAQI: 63&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_7325efd7bbc06da56c2fc23ce0fd9b77.setContent(html_026bad119ec162a2d42fc24d34d5b188);
#
#
#
#         marker_99dcf5788213ef2719672f5df6602764.bindPopup(popup_7325efd7bbc06da56c2fc23ce0fd9b77)
#         ;
#
#
#
#
#             var marker_a0b1c1b9e6c17086eb55fba6129d47e0 = L.marker(
#                 [46.058774, 11.038213],
#                 {}
#             ).addTo(map_3b7a8392c718fc28e3e4aae3c686b08c);
#
#
#             var icon_07dbed8809d04ea95ef93b6946f4249b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a0b1c1b9e6c17086eb55fba6129d47e0.setIcon(icon_07dbed8809d04ea95ef93b6946f4249b);
#
#
#         var popup_7376402339514b4c8aca420a2eb8f1dd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_091aa054656dc7f50591db23ebb7b13c = $(`&lt;div id=&quot;html_091aa054656dc7f50591db23ebb7b13c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CityID: IntermediatePoint&lt;br&gt;PredictedAQI: 62&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_7376402339514b4c8aca420a2eb8f1dd.setContent(html_091aa054656dc7f50591db23ebb7b13c);
#
#
#
#         marker_a0b1c1b9e6c17086eb55fba6129d47e0.bindPopup(popup_7376402339514b4c8aca420a2eb8f1dd)
#         ;
#
#
#
#
#             var marker_b0cb87eda1bd30c044d04c1f73169eb3 = L.marker(
#                 [46.053344, 11.214536],
#                 {}
#             ).addTo(map_3b7a8392c718fc28e3e4aae3c686b08c);
#
#
#             var icon_63ab25ccb48acef52d342fdcee3cdb9c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b0cb87eda1bd30c044d04c1f73169eb3.setIcon(icon_63ab25ccb48acef52d342fdcee3cdb9c);
#
#
#         var popup_24e2648bc4682990bacd6015e2b9ee4e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_22a3c93de28ca2a62eee03883fac7781 = $(`&lt;div id=&quot;html_22a3c93de28ca2a62eee03883fac7781&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CityID: IntermediatePoint&lt;br&gt;PredictedAQI: 62&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_24e2648bc4682990bacd6015e2b9ee4e.setContent(html_22a3c93de28ca2a62eee03883fac7781);
#
#
#
#         marker_b0cb87eda1bd30c044d04c1f73169eb3.bindPopup(popup_24e2648bc4682990bacd6015e2b9ee4e)
#         ;
#
#
#
#
#             var marker_5211fb6fbb1bfc6ba1bb320a4c776480 = L.marker(
#                 [46.050878, 10.947356],
#                 {}
#             ).addTo(map_3b7a8392c718fc28e3e4aae3c686b08c);
#
#
#             var icon_465c3e98f41703f18fbb5af8eb66a11

# %% [markdown]
# ### Finally, one last thing: let's reecreate the Map one final time, but with the updated heatmap.

# %%
#Creating the Map
DefinitiveMap = folium.Map(location=[41.50, 16.50], tiles = "Esri.WorldPhysical", zoom_start = 6,
               zoom_control = False,
               scrollWheelZoom = False,
               dragging = False)

#Adding Markers, Only Colored for Real Data Ones.
for row in SortedFilledLastRecordDF.iterrows():
    
    CityID = row[1]["CityID"]
    Latitude = row[1]["Latitude"]
    Longitude = row[1]["Longitude"]
    EuropeanAQI = row[1]["EuropeanAQI"]
    
    if CityID != "IntermediatePoint":
    
        if EuropeanAQI < 20:
            Color = "green"

        elif EuropeanAQI < 40 and EuropeanAQI >= 20:
            Color = "beige"

        elif EuropeanAQI < 60 and EuropeanAQI >= 40:
            Color = "orange"

        elif EuropeanAQI < 80 and EuropeanAQI >= 60:
            Color = "red"

        elif EuropeanAQI < 100 and EuropeanAQI >= 80:
            Color = "darkred"

        elif EuropeanAQI >= 100:
            Color = "black"

        #Place the markers with the popup labels and data
        DefinitiveMap.add_child(folium.Marker(
                                    location = (Latitude, Longitude),
                                    popup =
                                    "CityID: " + str(CityID) + "<br>" + "PredictedAQI: " + str(EuropeanAQI) + "<br>",
                                    icon = folium.Icon(color="%s" % Color),
                                )
                            )

#Not Adding Lines that connect Points, but generating the Heatmap.
HeatData = []

for row in SortedFilledLastRecordDF.iterrows():
    CityID = row[1]["CityID"]
    Coordinates = [row[1]["Latitude"], row[1]["Longitude"]]
    EuropeanAQI = row[1]["EuropeanAQI"]
    Data = [row[1]["Latitude"], row[1]["Longitude"], EuropeanAQI]
    
    #The Heatmap wants Data in format [Latitude, Longitude] or [Latitude, Longitude, Value]
    HeatData.append(Data)
    
folium.plugins.HeatMap(HeatData, radius = 40, blur = 55, min_opacity = 0.55, gradient = {0.4: "lime", 0.77: "yellow", 1: "red"}).add_to(DefinitiveMap)

# %%
DefinitiveMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_707db61ce798dbb46ee4709f0849200a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_707db61ce798dbb46ee4709f0849200a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_707db61ce798dbb46ee4709f0849200a = L.map(
#                 &quot;map_707db61ce798dbb46ee4709f0849200a&quot;,
#                 {
#                     center: [41.5, 16.5],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: false,
#                     preferCanvas: false,
#                     scrollWheelZoom: false,
#                     dragging: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2e1d34f9f84eaa735c6e4e4cde692cc1 = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Physical_Map/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: US National Park Service&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 8, &quot;maxZoom&quot;: 8, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2e1d34f9f84eaa735c6e4e4cde692cc1.addTo(map_707db61ce798dbb46ee4709f0849200a);
#
#
#             var marker_acac873f1bb85dbdb5255ddad02ba225 = L.marker(
#                 [46.066669, 11.12907],
#                 {}
#             ).addTo(map_707db61ce798dbb46ee4709f0849200a);
#
#
#             var icon_063931f17bc80fb897c58e725e1ab210 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_acac873f1bb85dbdb5255ddad02ba225.setIcon(icon_063931f17bc80fb897c58e725e1ab210);
#
#
#         var popup_2c284b32e614aa47c715e51ecf74a51b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3efb757fb669b9a45ec6512a9d43beca = $(`&lt;div id=&quot;html_3efb757fb669b9a45ec6512a9d43beca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CityID: TN&lt;br&gt;PredictedAQI: 63&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_2c284b32e614aa47c715e51ecf74a51b.setContent(html_3efb757fb669b9a45ec6512a9d43beca);
#
#
#
#         marker_acac873f1bb85dbdb5255ddad02ba225.bindPopup(popup_2c284b32e614aa47c715e51ecf74a51b)
#         ;
#
#
#
#
#             var marker_5ec754432f6266f4d13f1697b8526ec8 = L.marker(
#                 [45.735062, 7.31308],
#                 {}
#             ).addTo(map_707db61ce798dbb46ee4709f0849200a);
#
#
#             var icon_5fedc0bd9fe7e7a476fca8d4e9fdd240 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5ec754432f6266f4d13f1697b8526ec8.setIcon(icon_5fedc0bd9fe7e7a476fca8d4e9fdd240);
#
#
#         var popup_bf865b396d28d39858a20a62df9ce008 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2f0be8481bd4646bfd012bceb25dcb68 = $(`&lt;div id=&quot;html_2f0be8481bd4646bfd012bceb25dcb68&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CityID: AO&lt;br&gt;PredictedAQI: 26&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_bf865b396d28d39858a20a62df9ce008.setContent(html_2f0be8481bd4646bfd012bceb25dcb68);
#
#
#
#         marker_5ec754432f6266f4d13f1697b8526ec8.bindPopup(popup_bf865b396d28d39858a20a62df9ce008)
#         ;
#
#
#
#
#             var marker_b49a29cbd748ec47ef03431ba717ec06 = L.marker(
#                 [45.653599, 13.77852],
#                 {}
#             ).addTo(map_707db61ce798dbb46ee4709f0849200a);
#
#
#             var icon_4f52b976edc7850b26d2dc15178c1571 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b49a29cbd748ec47ef03431ba717ec06.setIcon(icon_4f52b976edc7850b26d2dc15178c1571);
#
#
#         var popup_9ea7bd046c311d4e9c542b34a09fc07d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c9b3a86bc8dd3b701623151f99ebfeba = $(`&lt;div id=&quot;html_c9b3a86bc8dd3b701623151f99ebfeba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CityID: TS&lt;br&gt;PredictedAQI: 33&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_9ea7bd046c311d4e9c542b34a09fc07d.setContent(html_c9b3a86bc8dd3b701623151f99ebfeba);
#
#
#
#         marker_b49a29cbd748ec47ef03431ba717ec06.bindPopup(popup_9ea7bd046c311d4e9c542b34a09fc07d)
#         ;
#
#
#
#
#             var marker_f73a6aa9aefba28b50c7300cbe31a4aa = L.marker(
#                 [45.464203, 9.189982],
#                 {}

# %% [markdown]
# ### TA-DAAAA!!!
# ### It's not the best map ever existed, but does its job.
# ### We can do a ton of engineering when plotting, we can get more data for smaller cities, we can use a different framework or we can fill more and more synthetic data to make it as dense as possible.
# ### For what's worth, I'm happy as it is now, so I won't be wasting too much time on this and I'll move on.
